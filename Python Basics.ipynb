# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevana-03/Python-Data-Science-Projects-/blob/main/Python%20Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello googke colab")
# Out:
# hello googke colab

# %%
print ("hello python")
print ("welcome to data science world")
# Out:
# hello python
# welcome to data science world

# %%
name = "jeevs"
age = 22
height = 5.4
print (name)
print (age)
print (height)
# Out:
# jeevs
# 22
# 5.4

# %%
x = 10
y = 3.14
z = "python"
a = "true"
print (type(x))
print (type(y))
print (type(z))
print (type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
name = input("enter your name")
print ("hello", name)
# Out:
# enter your namehello
# hello hello

# %%
a = 10
b = 20
print (a+b)
print (a-b)
print (a*b)
print (a/b)
# Out:
# 30
# -10
# 200
# 0.5

# %%
x = 20
if x > 18:
  print ("adult")
  print ("can vote")
# Out:
# adult
# can vote

# %%
x = 10
print(type(x))

name = "Jeevs"
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x = 10
x = "Python"
print(x)
# Out:
# Python

# %%
name = "Jeevs"
age = 24
height = 5.5
is_student = True

print(name)
print(age)
print(height)
print(is_student)

print(type(age))
print(type(height))
# Out:
# Jeevs
# 24
# 5.5
# True
# <class 'int'>
# <class 'float'>

# %%
age = int(age)
print (age+1)
# Out:
# 25

# %%
age = int(input("Enter age: "))
print(age + 1)
height = float(input("Enter height: "))
name = "jeevs"
text = str(num)
# Out:
# Enter age: 22
# 23
# Enter height: 4

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("My name is", name)
print("Next year my age will be", age + 1)
# Out:
# Enter your name: jeevana
# Enter your age: 20
# My name is jeevana
# Next year my age will be 21

# %%
a = 10
b = 3

print(a + b)   # Addition
print(a - b)   # Subtraction
print(a * b)   # Multiplication
print(a / b)   # Division
print(a % b)   # Modulus (remainder)
print(a ** b)  # Power
print(a // b)  # Floor division
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 1000
# 3

# %%
n = int(input("enter a number"))
print (n>0)
print (n%2==0)
# Out:
# enter a number6
# True
# True

# %%
age = 20
print (age>18)
# Out:
# True

# %%
age = 20
if age>18:
  print ('elilgible to vote')
else:
    print ('not eligible')
# Out:
# elilgible to vote

# %%
marks = 85

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade B

# %%
age = 20
has_id = True

if age >= 18:
    if has_id:
        print("Allowed inside")
    else:
        print("ID required")
else:
    print("Underage")
# Out:
# Allowed inside

# %%
num = int(input("enter a number"))
if n>0:
  print ("positive")
elif n<0:
  print ("negative")
else:
  print ("zero")
# Out:
# enter a number-1
# positive

# %%
n = int(input("enter a number"))
for i in range (1, 11):
  print(num, "x", i, "=", n*i)
# Out:
# enter a number7
# -1 x 1 = 7
# -1 x 2 = 14
# -1 x 3 = 21
# -1 x 4 = 28
# -1 x 5 = 35
# -1 x 6 = 42
# -1 x 7 = 49
# -1 x 8 = 56
# -1 x 9 = 63
# -1 x 10 = 70
